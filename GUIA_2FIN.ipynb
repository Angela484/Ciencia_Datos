# %% [markdown]
# # <p><center> GUIA 2</center></p>

# %% [markdown]
# ## CARGUE DEL DF Y CARACTERIZACIÓN

# %%
#Importación de la librería pandas
import pandas as pd

# %%
#lectura de la base de datos
df = pd.read_csv("10.000_Empresas_mas_Grandes_del_Pa_s_20240823.csv")

# %%
df["NIT"].nunique()
# Out:
# 11441

# %%
#verificación incial de la base de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NIT                     20000 non-null  int64
#  1   RAZÓN SOCIAL            19998 non-null  object
#  2   SUPERVISOR              20000 non-null  object
#  3   REGIÓN                  20000 non-null  object
#  4   DEPARTAMENTO DOMICILIO  20000 non-null  object
#  5   CIUDAD DOMICILIO        20000 non-null  object
#  6   CIIU                    20000 non-null  int64
#  7   MACROSECTOR             20000 non-null  object
#  8   INGRESOS OPERACIONALES  20000 non-null  object
#  9   GANANCIA (PÉRDIDA)      20000 non-null  object
#  10  TOTAL ACTIVOS           20000 non-null  object
#  11  TOTAL PASIVOS           20000 non-null  object
#  12  TOTAL PATRIMONIO        20000 non-null  object
#  13  Año de Corte            20000 non-null  int64
# dtypes: int64(3), object(11)
# memory usage: 2.1+ MB

# %%
#identificación de los nombres de las columnas
df.columns
# Out:
# Index(['NIT', 'RAZÓN SOCIAL', 'SUPERVISOR', 'REGIÓN', 'DEPARTAMENTO DOMICILIO',
#        'CIUDAD DOMICILIO', 'CIIU', 'MACROSECTOR', 'INGRESOS OPERACIONALES',
#        'GANANCIA (PÉRDIDA)', 'TOTAL ACTIVOS', 'TOTAL PASIVOS',
#        'TOTAL PATRIMONIO', 'Año de Corte'],
#       dtype='object')

# %%
len(df["NIT"].unique())
# Out:
# 11441

# %%
df["NIT"].nunique()
# Out:
# 11441

# %% [markdown]
# ## ACTIVIDAD 1: LIMPIEZA ITERATIVA

# %% [markdown]
# ### Producto
#
# ##### Escribir en un archivo tipo html de Jupyter  bloques de código y Markdown donde se tomen las variables de una base dada y se les realice lo siguiente:
#
# ###### Limpieza de un carácter especial.
# ###### Reducción de los nits de longitud mayor a 9.

# %%
#Colocar toda la base en mayúsculas 
df["REGIÓN"] = df["REGIÓN"].str.upper()

# %%
# Seleccionar columnas de tipo 'object' (cadenas de texto)
columnas_str = df.select_dtypes(include=['object']).columns.tolist()

print(columnas_str)
# Out:
# ['RAZÓN SOCIAL', 'SUPERVISOR', 'REGIÓN', 'DEPARTAMENTO DOMICILIO', 'CIUDAD DOMICILIO', 'MACROSECTOR', 'INGRESOS OPERACIONALES', 'GANANCIA (PÉRDIDA)', 'TOTAL ACTIVOS', 'TOTAL PASIVOS', 'TOTAL PATRIMONIO']

# %%
# En este proceso el for recorre todas las columnas y las convierte en minúsculas
for i in columnas_str:
    df[i] = df[i].str.lower()

# %%
#metodo para traer filas al azar (lo hago con el objetivo de verificar que la columna está en minúsculas)
df.sample(1)
# Out:
#             NIT  RAZÓN SOCIAL       SUPERVISOR     REGIÓN  \
# 7528  800172301  trasegar sas  supersociedades  antioquia
#
#      DEPARTAMENTO DOMICILIO    CIUDAD DOMICILIO  CIIU MACROSECTOR  \
# 7528              antioquia  medellin-antioquia  4659    comercio
#
#      INGRESOS OPERACIONALES GANANCIA (PÉRDIDA) TOTAL ACTIVOS TOTAL PASIVOS  \
# 7528                  $0.02              $0.00         $0.02         $0.01
#
#      TOTAL PATRIMONIO  Año de Corte
# 7528            $0.01          2022

# %%
# En este proceso el for recorre todas las columnas y las convierte en mayúsculas
for i in columnas_str:
    df[i] = df[i].str.upper()

# %%
#metodo para traer filas al azar (lo hago con el objetivo de verificar que la columna está en mayúsculas)
df.sample(1)
# Out:
#              NIT             RAZÓN SOCIAL       SUPERVISOR  \
# 14863  860030764  BETANIA COLOMBIA S.A.S.  SUPERSOCIEDADES
#
#                       REGIÓN DEPARTAMENTO DOMICILIO         CIUDAD DOMICILIO  \
# 14863  BOGOTÁ - CUNDINAMARCA            BOGOTA D.C.  BOGOTA D.C.-BOGOTA D.C.
#
#        CIIU MACROSECTOR INGRESOS OPERACIONALES GANANCIA (PÉRDIDA)  \
# 14863  6810   SERVICIOS                  $0.03              $0.05
#
#       TOTAL ACTIVOS TOTAL PASIVOS TOTAL PATRIMONIO  Año de Corte
# 14863         $0.52         $0.10            $0.42          2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NIT                     20000 non-null  int64
#  1   RAZÓN SOCIAL            19998 non-null  object
#  2   SUPERVISOR              20000 non-null  object
#  3   REGIÓN                  20000 non-null  object
#  4   DEPARTAMENTO DOMICILIO  20000 non-null  object
#  5   CIUDAD DOMICILIO        20000 non-null  object
#  6   CIIU                    20000 non-null  int64
#  7   MACROSECTOR             20000 non-null  object
#  8   INGRESOS OPERACIONALES  20000 non-null  object
#  9   GANANCIA (PÉRDIDA)      20000 non-null  object
#  10  TOTAL ACTIVOS           20000 non-null  object
#  11  TOTAL PASIVOS           20000 non-null  object
#  12  TOTAL PATRIMONIO        20000 non-null  object
#  13  Año de Corte            20000 non-null  int64
# dtypes: int64(3), object(11)
# memory usage: 2.1+ MB

# %%
#Limpieza de datos en blanco para variables string, al inicio y final de la cadena.
#(primer ejercicio, no lo elimino porque con esto entiendo como funciona el for)

#df["RAZÓN SOCIAL"] = df["RAZÓN SOCIAL"].str.strip()
#df["SUPERVISOR"] = df["SUPERVISOR"].str.strip()
#df["REGIÓN"] = df["REGIÓN"].str.strip()
#df["DEPARTAMENTO DOMICILIO"] = df["DEPARTAMENTO DOMICILIO"].str.strip()

# %%
# En este proceso el for recorre todas las columnas y las convierte en mayúsculas
for i in columnas_str:
    df[i] = df[i].str.strip()

# %%
#Limpieza del $ en las variables que lo contienen
#(primer ejercicio, no lo elimino porque con esto entiendo como funciona el for)
#df['TOTAL ACTIVOS'] = df['TOTAL ACTIVOS'].str.replace('$', '', regex=False).str.strip()
#df['INGRESOS OPERACIONALES'] = df['INGRESOS OPERACIONALES'].str.replace('$', '', regex=False).str.strip()
#df['GANANCIA (PÉRDIDA)'] = df['GANANCIA (PÉRDIDA)'].str.replace('$', '', regex=False).str.strip()
#df['TOTAL PASIVOS'] = df['TOTAL PASIVOS'].str.replace('$', '', regex=False).str.strip()
#df['TOTAL PATRIMONIO'] = df['TOTAL PATRIMONIO'].str.replace('$', '', regex=False).str.strip()

# %%
# En este proceso el for recorre todas las columnas y quita los signos "$"
for i in columnas_str:
    df[i] = df[i].str.replace('$', '', regex=False).str.strip()

# %%
df.sample(1)
# Out:
#              NIT        RAZÓN SOCIAL       SUPERVISOR                 REGIÓN  \
# 11644  830050856  MILLENIUM BPO S.A.  SUPERSOCIEDADES  BOGOTÁ - CUNDINAMARCA
#
#       DEPARTAMENTO DOMICILIO    CIUDAD DOMICILIO  CIIU MACROSECTOR  \
# 11644           CUNDINAMARCA  COTA -CUNDINAMARCA  8220   SERVICIOS
#
#       INGRESOS OPERACIONALES GANANCIA (PÉRDIDA) TOTAL ACTIVOS TOTAL PASIVOS  \
# 11644                   0.12               0.00          0.07          0.05
#
#       TOTAL PATRIMONIO  Año de Corte
# 11644             0.02          2021

# %%
#limpieza de la tílde sin usar otras librerías
#df['REGIÓN'] = df['REGIÓN'].str.replace('Á', 'A')
for i in columnas_str:
    df[i] = df[i].str.replace('Á', 'A')
    df[i] = df[i].str.replace('É', 'E')
    df[i] = df[i].str.replace('Í', 'I')
    df[i] = df[i].str.replace('Ó', 'O')
    df[i] = df[i].str.replace('Ú', 'U')

# %%
#Verificación de que se hayan aplicado los ajustes 
df.sample(30)
# Out:
#              NIT                                       RAZÓN SOCIAL  \
# 17337  901279219                                 CIPLA COLOMBIA SAS
# 11107  890923691                           RODRIGUEZ Y LONDOÑO S.A.
# 18599  900398767               CARRAO ENERGY S.A. SUCURSAL COLOMBIA
# 16152  900225474                                SCALPI COSMETICA SA
# 17725  900076922               PORCELANATOS Y PISOS DE COLOMBIA SAS
# 10303  900499032                                STECKERL ACEROS SAS
# 7421   860353684                                  SALVAGUARDAR LTDA
# 19454  900729243                              EQUIPMASTER STORE SAS
# 10176  830025448                                GRUPO BOLIVAR S. A.
# 19679  800115574              SERVICIOS Y ASESORIAS DEL LITORAL SAS
# 5641   860009807           INDEPENDIENTE SANTA FE EN REORGANIZACION
# 9161   830045053                                 CABLE SERVICIOS SA
# 1294   901181764                           C.I UPFIELD COLOMBIA SAS
# 16897  890927931  ELECTRICOS DE COLOMBIA SOCIEDAD ANONIMA EN PRO...
# 504    890801339               COMPAÑIA MANUFACTURERA MANISOL S.ALO
# 17956  900243676                           INVERSIONES HYBISCUS SAS
# 12380  800143273               MONTAJES Y CONSTRUCCIONES FERMAR SAS
# 4284   830031687            POLUX SUMINISTROS SAS EN REORGANIZACION
# 13862  800042169            MEMPHIS PRODUCTS S.A. EN REORGANIZACION
# 19543  806008176                 COMERCIALIZADORA EL CONSTRUCTOR SA
# 16223  900124603                  CENTRO DERMATOLOGICO DE CALI S.A.
# 11895  900969200                                AUTOMOTOR.CO S.A.S.
# 18181  901329330                        Z-COL LLC SUCURSAL COLOMBIA
# 17614  900967670                                HG SANTAMARIA S.A.S
# 4637   890320876                             O TAFUR Z Y CIA S EN C
# 4998   900158281                                         INRAMA SAS
# 19742  900157842                          TECNO LITE COLOMBIA S.A.S
# 8541   900386708  INGENIERIA DE CONSTRUCCION Y MINERIA DE COLOMB...
# 1359   900184924                                  ROBERT BOSCH LTDA
# 16206  901157108                          HABITAR IMPORTACIONES SAS
#
#             SUPERVISOR                 REGIÓN DEPARTAMENTO DOMICILIO  \
# 17337  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 11107  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 18599  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 16152  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA           CUNDINAMARCA
# 17725  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 10303  SUPERSOCIEDADES        COSTA ATLANTICA              ATLANTICO
# 7421   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 19454  SUPERSOCIEDADES        COSTA ATLANTICA              ATLANTICO
# 10176  SUPERFINANCIERA  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 19679  SUPERSOCIEDADES        COSTA ATLANTICA                  CESAR
# 5641   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 9161   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 1294   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 16897  SUPERSOCIEDADES              ANTIOQUIA              ANTIOQUIA
# 504    SUPERSOCIEDADES           EJE CAFETERO                 CALDAS
# 17956  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 12380  SUPERSOCIEDADES       CENTRO - ORIENTE              SANTANDER
# 4284   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA           CUNDINAMARCA
# 13862  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 19543  SUPERSOCIEDADES        COSTA ATLANTICA                BOLIVAR
# 16223       SUPERSALUD         COSTA PACIFICA                  VALLE
# 11895  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 18181  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 17614  SUPERSOCIEDADES              ANTIOQUIA              ANTIOQUIA
# 4637   SUPERSOCIEDADES         COSTA PACIFICA                  VALLE
# 4998   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 19742  SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 8541   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 1359   SUPERSOCIEDADES  BOGOTA - CUNDINAMARCA            BOGOTA D.C.
# 16206  SUPERSOCIEDADES        COSTA ATLANTICA              ATLANTICO
#
#                 CIUDAD DOMICILIO  CIIU   MACROSECTOR INGRESOS OPERACIONALES  \
# 17337    BOGOTA D.C.-BOGOTA D.C.  4645      COMERCIO                   0.02
# 11107    BOGOTA D.C.-BOGOTA D.C.  4659      COMERCIO                   0.18
# 18599    BOGOTA D.C.-BOGOTA D.C.   610        MINERO                   0.02
# 16152         COTA -CUNDINAMARCA  2023   MANUFACTURA                   0.02
# 17725    BOGOTA D.C.-BOGOTA D.C.  4669      COMERCIO                   0.02
# 10303           GALAPA-ATLANTICO  4663      COMERCIO                   0.65
# 7421     BOGOTA D.C.-BOGOTA D.C.  8010     SERVICIOS                   0.02
# 19454     BARRANQUILLA-ATLANTICO  4653      COMERCIO                   0.01
# 10176    BOGOTA D.C.-BOGOTA D.C.  6492     SERVICIOS                   1.02
# 19679           VALLEDUPAR-CESAR  7820     SERVICIOS                   0.01
# 5641     BOGOTA D.C.-BOGOTA D.C.  9312     SERVICIOS                   0.04
# 9161     BOGOTA D.C.-BOGOTA D.C.  4652      COMERCIO                   0.02
# 1294     BOGOTA D.C.-BOGOTA D.C.  1089   MANUFACTURA                   0.20
# 16897         MEDELLIN-ANTIOQUIA  4663      COMERCIO                   0.02
# 504             MANIZALES-CALDAS  4772      COMERCIO                   0.51
# 17956    BOGOTA D.C.-BOGOTA D.C.  8299     SERVICIOS                   0.02
# 12380  BARRANCABERMEJA-SANTANDER  4290  CONSTRUCCION                   0.08
# 4284          COTA -CUNDINAMARCA  4651      COMERCIO                   0.05
# 13862    BOGOTA D.C.-BOGOTA D.C.  4645      COMERCIO                   0.05
# 19543          CARTAGENA-BOLIVAR  4663      COMERCIO                   0.01
# 16223                 CALI-VALLE  8699     SERVICIOS                   0.02
# 11895    BOGOTA D.C.-BOGOTA D.C.  4511      COMERCIO                   0.10
# 18181    BOGOTA D.C.-BOGOTA D.C.   910        MINERO                   0.02
# 17614         MEDELLIN-ANTIOQUIA  7010     SERVICIOS                   0.02
# 4637                  CALI-VALLE   145  AGROPECUARIO                   0.05
# 4998     BOGOTA D.C.-BOGOTA D.C.  6810     SERVICIOS                   0.04
# 19742    BOGOTA D.C.-BOGOTA D.C.  4669      COMERCIO                   0.01
# 8541     BOGOTA D.C.-BOGOTA D.C.  4290  CONSTRUCCION                   0.02
# 1359     BOGOTA D.C.-BOGOTA D.C.  4659      COMERCIO                   0.19
# 16206     BARRANQUILLA-ATLANTICO  4663      COMERCIO                   0.02
#
#       GANANCIA (PÉRDIDA) TOTAL ACTIVOS TOTAL PASIVOS TOTAL PATRIMONIO  \
# 17337               0.00          0.01          0.01             0.01
# 11107               0.00          0.11          0.08             0.02
# 18599               0.00          0.04          0.03             0.01
# 16152               0.00          0.05          0.02             0.02
# 17725               0.00          0.03          0.00             0.02
# 10303               0.09          0.42          0.28             0.13
# 7421                0.00          0.01          0.00             0.01
# 19454               0.00          0.00          0.00             0.00
# 10176               0.97         13.80          1.61            12.19
# 19679               0.00          0.00          0.00             0.00
# 5641                0.00          0.04          0.04             0.00
# 9161                0.00          0.02          0.01             0.02
# 1294               -0.01          0.31          0.21             0.11
# 16897               0.00          0.01          0.01            -0.00
# 504                 0.01          0.35          0.27             0.09
# 17956               0.01          0.14          0.01             0.13
# 12380               0.01          0.03          0.01             0.02
# 4284               -0.00          0.04          0.04             0.00
# 13862               0.00          0.04          0.04             0.00
# 19543               0.00          0.01          0.00             0.01
# 16223               0.00          0.03          0.02             0.01
# 11895              -0.00          0.06          0.05             0.01
# 18181              -0.00          0.03          0.00             0.02
# 17614               0.02          0.32          0.01             0.31
# 4637                0.00          0.03          0.01             0.01
# 4998                0.01          0.04          0.03             0.01
# 19742               0.00          0.02          0.01             0.01
# 8541                0.00          0.01          0.01             0.01
# 1359                0.00          0.15          0.13             0.02
# 16206               0.00          0.01          0.01             0.00
#
#        Año de Corte
# 17337          2021
# 11107          2021
# 18599          2021
# 16152          2021
# 17725          2021
# 10303          2021
# 7421           2022
# 19454          2021
# 10176          2021
# 19679          2021
# 5641           2022
# 9161           2022
# 1294           2022
# 16897          2021
# 504            2022
# 17956          2021
# 12380          2021
# 4284           2022
# 13862          2021
# 19543          2021
# 16223          2021
# 11895          2021
# 18181          2021
# 17614          2021
# 4637           2022
# 4998           2022
# 19742          2021
# 8541           2022
# 1359           2022
# 16206          2021

# %% [markdown]
# ## ACTIVIDAD 2: TRANSFORMACIÓN DE DATOS

# %% [markdown]
# ### Producto
#
# ##### Escribir en un archivo tipo html de Jupyter  bloques de código y Markdown donde se tomen las variables de una base dada y se les realice lo siguiente:
#
# ##### Transformación del tipo de dato

# %%
print(df["TOTAL ACTIVOS"].dtypes)
# Out:
# object

# %%
#Verificación incial del tipo de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NIT                     20000 non-null  int64
#  1   RAZÓN SOCIAL            19998 non-null  object
#  2   SUPERVISOR              20000 non-null  object
#  3   REGIÓN                  20000 non-null  object
#  4   DEPARTAMENTO DOMICILIO  20000 non-null  object
#  5   CIUDAD DOMICILIO        20000 non-null  object
#  6   CIIU                    20000 non-null  int64
#  7   MACROSECTOR             20000 non-null  object
#  8   INGRESOS OPERACIONALES  20000 non-null  object
#  9   GANANCIA (PÉRDIDA)      20000 non-null  object
#  10  TOTAL ACTIVOS           20000 non-null  object
#  11  TOTAL PASIVOS           20000 non-null  object
#  12  TOTAL PATRIMONIO        20000 non-null  object
#  13  Año de Corte            20000 non-null  int64
# dtypes: int64(3), object(11)
# memory usage: 2.1+ MB

# %%
#transformación del tipo de dato de string a float, para las variables númericas.
df['INGRESOS OPERACIONALES'] = df['INGRESOS OPERACIONALES'].astype(float)
df['GANANCIA (PÉRDIDA)'] = df['GANANCIA (PÉRDIDA)'].astype(float)
df['TOTAL ACTIVOS'] = df['TOTAL ACTIVOS'].astype(float)
df['TOTAL PASIVOS'] = df['TOTAL PASIVOS'].astype(float)
df['TOTAL PATRIMONIO'] = df['TOTAL PATRIMONIO'].astype(float)

# %%
#Vefificación de que la variable cambió de tipo de dato
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NIT                     20000 non-null  int64
#  1   RAZÓN SOCIAL            19998 non-null  object
#  2   SUPERVISOR              20000 non-null  object
#  3   REGIÓN                  20000 non-null  object
#  4   DEPARTAMENTO DOMICILIO  20000 non-null  object
#  5   CIUDAD DOMICILIO        20000 non-null  object
#  6   CIIU                    20000 non-null  int64
#  7   MACROSECTOR             20000 non-null  object
#  8   INGRESOS OPERACIONALES  20000 non-null  float64
#  9   GANANCIA (PÉRDIDA)      20000 non-null  float64
#  10  TOTAL ACTIVOS           20000 non-null  float64
#  11  TOTAL PASIVOS           20000 non-null  float64
#  12  TOTAL PATRIMONIO        20000 non-null  float64
#  13  Año de Corte            20000 non-null  int64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 2.1+ MB
